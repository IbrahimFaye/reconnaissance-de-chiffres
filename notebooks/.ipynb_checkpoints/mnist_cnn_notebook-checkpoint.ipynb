# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D,MaxPooling2D,Flatten,Dropout
from tensorflow.keras.datasets import mnist
import os
from tensorflow.keras.utils import to_categorical

# %%
(x_train,y_train),(x_test,y_test)= mnist.load_data()

# %%
print(x_train.shape)
print(x_test.shape)
# Out:
# (60000, 28, 28)
# (10000, 28, 28)

# %% [markdown]
# Prétraitement

# %%
x_train=x_train.reshape(-1,28,28,1).astype('float32')/255.0
x_test=x_test.reshape(-1,28,28,1).astype('float32')/255.0

y_train=to_categorical(y_train)
y_test=to_categorical(y_test)

# %% [markdown]
# modelisation

# %%
model = Sequential([
    Conv2D(32,(3,3), activation='relu', input_shape=(28,28,1)),
    MaxPooling2D((2,2)),

    Conv2D(64,(3,3), activation='relu'),
    MaxPooling2D((2,2)),

    Conv2D(128, (3,3), activation='relu'),
    Flatten(),

    Dense(128, activation='relu'),
    Dropout(0.5),
    Dense(10, activation='softmax')
])

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
from tensorflow.keras.callbacks import ReduceLROnPlateau

history1= model.fit(x_train, y_train, epochs=10, batch_size =128, validation_split=0.1)

loss,acc= model.evaluate(x_test,y_test)
print(f'accuracy: {acc}')
# Out:
# Epoch 1/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 52s 118ms/step - accuracy: 0.3257 - loss: 1.8315 - val_accuracy: 0.8973 - val_loss: 0.3423
# Epoch 2/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 50s 118ms/step - accuracy: 0.8417 - loss: 0.5040 - val_accuracy: 0.9365 - val_loss: 0.2057
# Epoch 3/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 49s 116ms/step - accuracy: 0.8922 - loss: 0.3526 - val_accuracy: 0.9543 - val_loss: 0.1514
# Epoch 4/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 50s 119ms/step - accuracy: 0.9173 - loss: 0.2695 - val_accuracy: 0.9662 - val_loss: 0.1165
# Epoch 5/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 81s 117ms/step - accuracy: 0.9350 - loss: 0.2130 - val_accuracy: 0.9638 - val_loss: 0.1162
# Epoch 6/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 51s 120ms/step - accuracy: 0.9442 - loss: 0.1862 - val_accuracy: 0.9765 - val_loss: 0.0901
# Epoch 7/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 81s 117ms/step - accuracy: 0.9507 - loss: 0.1662 - val_accuracy: 0.9762 - val_loss: 0.0829
# Epoch 8/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 83s 119ms/step - accuracy: 0.9570 - loss: 0.1428 - val_accuracy: 0.9800 - val_loss: 0.0704
# Epoch 9/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 52s 124ms/step - accuracy: 0.9626 - loss: 0.1282 - val_accuracy: 0.9807 - val_loss: 0.0687
# Epoch 10/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 80s 120ms/step - accuracy: 0.9657 - loss: 0.1149 - val_accuracy: 0.9820 - val_loss: 0.0633
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.9750 - loss: 0.0762
# accuracy: 0.9783999919891357

# %% [markdown]
# visualisation 1

# %%
plt.plot(history1.history['accuracy'])
plt.plot(history1.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
plt.plot(history1.history['loss'])
plt.plot(history1.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %% [markdown]
# data augmentation

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

datagen= ImageDataGenerator(
    rotation_range=10,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=False,
)

history= model.fit(datagen.flow(x_train,y_train,batch_size=128),epochs=10,validation_data=(x_test,y_test))

loss,acc= model.evaluate(x_test,y_test)
print(f'accuracy: {acc}')
# Out:
# Epoch 1/10
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 85s 178ms/step - accuracy: 0.8520 - loss: 0.4917 - val_accuracy: 0.9737 - val_loss: 0.0767
# Epoch 2/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 82s 174ms/step - accuracy: 0.9065 - loss: 0.3141 - val_accuracy: 0.9795 - val_loss: 0.0589
# Epoch 3/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 83s 176ms/step - accuracy: 0.9239 - loss: 0.2606 - val_accuracy: 0.9812 - val_loss: 0.0547
# Epoch 4/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 80s 170ms/step - accuracy: 0.9311 - loss: 0.2298 - val_accuracy: 0.9816 - val_loss: 0.0507
# Epoch 5/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 80s 170ms/step - accuracy: 0.9399 - loss: 0.2047 - val_accuracy: 0.9844 - val_loss: 0.0477
# Epoch 6/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 80s 170ms/step - accuracy: 0.9428 - loss: 0.1910 - val_accuracy: 0.9849 - val_loss: 0.0493
# Epoch 7/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 78s 166ms/step - accuracy: 0.9460 - loss: 0.1812 - val_accuracy: 0.9843 - val_loss: 0.0482
# Epoch 8/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 78s 165ms/step - accuracy: 0.9491 - loss: 0.1704 - val_accuracy: 0.9839 - val_loss: 0.0435
# Epoch 9/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 77s 163ms/step - accuracy: 0.9506 - loss: 0.1616 - val_accuracy: 0.9857 - val_loss: 0.0424
# Epoch 10/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 77s 164ms/step - accuracy: 0.9537 - loss: 0.1517 - val_accuracy: 0.9852 - val_loss: 0.0463
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.9824 - loss: 0.0553
# accuracy: 0.9851999878883362

# %% [markdown]
# Visualisation 2

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %% [markdown]
# Batch Normalization

# %%
from tensorflow.keras.layers import BatchNormalization

model = Sequential([
    Conv2D(32,(3,3), activation='relu', input_shape=(28,28,1)),
    BatchNormalization(),
    MaxPooling2D((2,2)),

    Conv2D(64,(3,3), activation='relu'),
    BatchNormalization(),
    MaxPooling2D((2,2)),

    Conv2D(128, (3,3), activation='relu'),
    BatchNormalization(),
    Flatten(),

    Dense(128, activation='relu'),
    Dropout(0.5),
    Dense(10, activation='softmax')
])

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

datagen= ImageDataGenerator(
    rotation_range=10,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=False,
)

# %%
lr_scheduler = ReduceLROnPlateau(
    monitor="val_loss", factor=0.5, patience=2, verbose=1
)
history2 = model.fit(
    datagen.flow(x_train, y_train, batch_size=128),
    epochs=15,
    validation_data=(x_test, y_test),
    callbacks=[lr_scheduler]
)
loss,acc= model.evaluate(x_test,y_test)
print(f'accuracy: {acc}')
# Out:
# Epoch 1/15
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 112s 226ms/step - accuracy: 0.7968 - loss: 0.6472 - val_accuracy: 0.9770 - val_loss: 0.1016 - learning_rate: 0.0010
# Epoch 2/15
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 139s 220ms/step - accuracy: 0.9601 - loss: 0.1341 - val_accuracy: 0.9895 - val_loss: 0.0296 - learning_rate: 0.0010
# Epoch 3/15
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 105s 225ms/step - accuracy: 0.9710 - loss: 0.1006 - val_accuracy: 0.9896 - val_loss: 0.0326 - learning_rate: 0.0010
# Epoch 4/15
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 105s 225ms/step - accuracy: 0.9773 - loss: 0.0792 - val_accuracy: 0.9913 - val_loss: 0.0270 - learning_rate: 0.0010
# Epoch 5/15
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 104s 222ms/step - accuracy: 0.9791 - loss: 0.0717 - val_accuracy: 0.9892 - val_loss: 0.0396 - learning_rate: 0.0010
# Epoch 6/15
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 105s 225ms/step - accuracy: 0.9804 - loss: 0.0657 - val_accuracy: 0.9934 - val_loss: 0.0261 - learning_rate: 0.0010
# Epoch 7/15
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 105s 223ms/step - accuracy: 0.9815 - loss: 0.0658 - val_accuracy: 0.9937 - val_loss: 0.0221 - learning_rate: 0.0010
# Epoch 8/15
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 104s 222ms/step - accuracy: 0.9844 - loss: 0.0555 - val_accuracy: 0.9931 - val_loss: 0.0236 - learning_rate: 0.0010
# Epoch 9/15
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step - accuracy: 0.9855 - loss: 0.0521
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 105s 224ms/step - accuracy: 0.9855 - loss: 0.0521 - val_accuracy: 0.9892 - val_loss: 0.0355 - learning_rate: 0.0010
# Epoch 10/15
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 104s 222ms/step - accuracy: 0.9875 - loss: 0.0444 - val_accuracy: 0.9942 - val_loss: 0.0190 - learning_rate: 5.0000e-04
# Epoch 11/15
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 108s 231ms/step - accuracy: 0.9896 - loss: 0.0366 - val_accuracy: 0.9947 - val_loss: 0.0163 - learning_rate: 5.0000e-04
# Epoch 12/15
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 105s 224ms/step - accuracy: 0.9893 - loss: 0.0368 - val_accuracy: 0.9952 - val_loss: 0.0162 - learning_rate: 5.0000e-04
# Epoch 13/15
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 107s 228ms/step - accuracy: 0.9900 - loss: 0.0358 - val_accuracy: 0.9939 - val_loss: 0.0208 - learning_rate: 5.0000e-04
# Epoch 14/15
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 111s 237ms/step - accuracy: 0.9894 - loss: 0.0358 - val_accuracy: 0.9948 - val_loss: 0.0152 - learning_rate: 5.0000e-04
# Epoch 15/15
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 107s 228ms/step - accuracy: 0.9909 - loss: 0.0312 - val_accuracy: 0.9937 - val_loss: 0.0203 - learning_rate: 5.0000e-04
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.9914 - loss: 0.0260
# accuracy: 0.9937000274658203

# %%
model.save("mnist_cnn.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
from google.colab import files

files.download("mnist_cnn.h5")

# %% [markdown]
# visualisation 3

# %%
plt.figure(figsize=(8,5))
plt.plot(history2.history['accuracy'], label='Train Accuracy')
plt.plot(history2.history['val_accuracy'], label='Validation Accuracy')
plt.title("Courbes d'Accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.plot(history2.history['loss'], label='Train Loss')
plt.plot(history2.history['val_loss'], label='Validation Loss')
plt.title("Courbes de la Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.grid(True)
plt.show()

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

y_pred = model.predict(x_test)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true = np.argmax(y_test, axis=1)

cm = confusion_matrix(y_true, y_pred_classes)

plt.figure(figsize=(8,6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
plt.title("Matrice de Confusion - CNN MNIST")
plt.xlabel("Prédiction")
plt.ylabel("Vérité terrain")
plt.show()
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step
